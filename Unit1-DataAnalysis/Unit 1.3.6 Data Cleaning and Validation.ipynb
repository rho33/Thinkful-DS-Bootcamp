# %% [markdown]
# # Assignment
# 1. Determine the five most common journals and the total articles for each.
# 2. Calculate the mean, median, and standard deviation of the open-access cost per article for each journal

# %%
import numpy as np
import pandas as pd
from fuzzywuzzy import fuzz
from itertools import combinations
from hunspell import Hunspell
import re
import time
import os

# %%
def clean_title(s):
    cs = s.strip().lower()
    cs = re.sub(r'&', 'and', cs) #replace ampersand with and
    cs = re.sub(r'[^a-zA-Z0-9]', ' ', cs) #replace non alpha numeric with space

    cs = re.sub(r'\A\s*(j|jnl)(\s+)',' journal ',cs) #replace j and jnl at beginning of string with journal
    cs = re.sub(r'\s+(j|jnl)(\s+)',' journal ',cs) #replace j and jnl not at beginning of string with journal
    
    cs = re.sub(r'\s+chem\s+',' chemistry ',cs) #replace chem with chemistry middle of word
    cs = re.sub(r'\s+chem\Z',' chemistry ',cs) #replace chem with chemistry end of word
    
    cs = re.sub(r'\s+biol\s+',' biological ',cs) #replace biol in middle of word with biological
    cs = re.sub(r'\s*biol\Z',' biology ',cs) #replace biol at end of word with biology
    
    cs = re.sub(r'\s*biol open\s*',' biology open ',cs) #replace biol open with biology open
    
    cs = re.sub(r'\s+med\s+',' medicinal ',cs) #replace med with medical
    cs = re.sub(r'\s*1\s*',' one ',cs) #replace 1 with one
    cs = re.sub(r'\s*public library of science\s*',' plos ',cs) #replace public library of science with plos
    
    cs = re.sub(r'\s+immunol\s+',' immunology ',cs) #replace immunol with immunology middle of string
    cs = re.sub(r'\s+immunol\Z',' immunology ',cs) #replace immunol with immunology end of string
    cs = re.sub(r'\Aimmunol\s+',' immunology ',cs) #replace immunol with immunology beginning of string
    
    cs = re.sub(r'\s+org\s+',' organic ',cs) #replace org with organic
    cs = re.sub(r'\s*eur\s+',' european ',cs) #replace eur with european
    
    cs = re.sub(r'\s+mol\s+',' molecular ',cs) #replace mol with molecular middle of string
    cs = re.sub(r'\Amol\s+',' molecular ',cs) #replace mol with molecular beginning of string

    
    cs = re.sub(r'\s+sci\s+',' science ',cs) #replace sci with science
    
    
    cs = re.sub(r'\s+bioeth\s+',' bioethics ',cs) #replace bioeth with bioethics
    cs = re.sub(r'\s+bioeth\Z',' bioethics',cs) #replace bioeth with bioethics
    
    cs = re.sub(r'\s*acta d\s*',' acta crystallographica d ',cs) #replace acta d  with acta crystallographica d
    cs = re.sub(r'\s*acta f\s*',' acta crystallographica f ',cs) #replace acta f  with acta crystallographica f
    cs = re.sub(r'\s+section\s+','',cs) #remove section
    cs = re.sub(r'plosone',' plos one ',cs) #replace plosone with plos one
    
    cs = re.sub(r'.*national academy of sciences',' pnas ',cs) #proceedings of the national academy of sciences to pnas
    cs = re.sub(r'.*pnas.*','pnas',cs) #reduce anything with pnas in it to only pnas
    
    cs = re.sub(r'j clin microbiol',' journal of clinical microbiology ',cs) 
    
    cs = re.sub(r'\s+dis\s+',' disease ',cs) #dis to disease in middle of string
    cs = re.sub(r'\s+dis\Z',' disease',cs) #dis to disease at end of string
    
    cs = re.sub(r'\s+infect\s+',' infectious ',cs) #infect to infectious in middle of string
    cs = re.sub(r'\s+infect\Z',' infections ',cs) #infect to infections at end of string

    cs = re.sub(r'journal of acquired immune deficiency syndromes',' jaids ',cs) #proceedings of the national academy of sciences to pnas
    cs = re.sub(r'.*jaids.*',' jaids ',cs) #reduce anything with jaids in it to only jaids
    
    cs = re.sub(r'\s+virol\Z',' virology ',cs) #virol at end of input to virology

    cs = re.sub(r'\s+pharm\Z',' pharmacology ',cs) #pharm at end of word to pharmacology
    
    cs = re.sub(r'\s+biotechnol\s+',' biotechnology ',cs)# biotechnol to biotechnology in middle of word
    cs = re.sub(r'\s+biotechnol\Z',' biotechnology ',cs)# biotechnol to biotechnology at end of word
    cs = re.sub(r'\Abiotechnol\s+',' biotechnology ',cs)# biotechnol to biotechnology at beginning of word
    
    cs = re.sub(r'\s+biochem\s+',' biochemical ',cs)# biochem to biochemical in middle of word
    cs = re.sub(r'\Abiochem\s+',' biochemical ',cs)# biochem to biochemical at beginning of word
    
    cs = re.sub(r'\Aimplement\s+',' implementation ',cs)# implement to implementation at beginning of word

    cs = re.sub(r'\s+transm\s+',' transmitted ',cs) #transm to transmitted
    
    cs = re.sub(r'\Aam\s+',' American ', cs)
    
    cs = re.sub(r'\Adev\s+',' developing ', cs)
    
    cs = cs.strip().lower()
    return cs

# %%
wt = pd.read_csv('WELLCOME_APCspend2013_forThinkful.csv', encoding = "ISO-8859-1")

# %% [markdown]
# # Clean "Journal title" Column

# %%
#strip, lower case  Journal titles
wt['Journal title'] = wt['Journal title'].str.strip().str.lower().fillna('')

# %%
wt['cleansed_journal_title'] = wt['Journal title'].apply(clean_title)
wt
# Out:
#                             PMID/PMCID  \
# 0                                  NaN
# 1                           PMC3679557
# 2                23043264  PMC3506128
# 3                  23438330 PMC3646402
# 4                 23438216 PMC3601604
# 5                           PMC3579457
# 6                           PMC3709265
# 7                 23057412 PMC3495574
# 8                    PMCID: PMC3780468
# 9                    PMCID: PMC3621575
# 10                   PMCID: PMC3739413
# 11                   PMCID: PMC3530961
# 12                   PMCID: PMC3624797
# 13                          PMC3413243
# 14                          PMC3694353
# 15                          PMC3572711
# 16                            22610094
# 17                   PMCID: PMC3586974
# 18        23455506  PMCID: PMC3607399
# 19          PMID: 24015914 PMC3833349
# 20                       : PMC3805332
# 21                                 NaN
# 22            PMCID:\n    PMC3656742\n
# 23                      PMCID: 3584654
# 24                 22971149 PMC3466778
# 25                            23072351
# 26                          PMC3477822
# 27                          PMC3530960
# 28                23458425 PMC3630740
# 29                      PMID: 20146481
# ...                                ...
# 2097                           3575693
# 2098        PMID: 22188548 PMC3492912
# 2099        PMID: 22764734 PMC3798095
# 2100                    PMID: 23703895
# 2101                 PMCID: PMC3664106
# 2102                    PMID: 23649934
# 2103                        PMC2955965
# 2104        PMID: 19948006 PMC3551259
# 2105                    PMID: 23305527
# 2106                 PMCID: PMC3600532
# 2107                        PMC3440570
# 2108              23670821 PMC3738939
# 2109                          23640856
# 2110                    PMID: 23918316
# 2111                 PMCID: PMC3728731
# 2112       23495205685.88 PMC3743159
# 2113         PMID:22997008 PMC3569869
# 2114                           3708104
# 2115                        PMC3713766
# 2116                        PMC3819359
# 2117                       PMC3773237
# 2118                       PMC3815011
# 2119                        PMC3805356
# 2120                             Epub
# 2121                        PMC3707567
# 2122                           2901593
# 2123                           3748854
# 2124                           3785148
# 2125          PMCID:\n    PMC3647051\n
# 2126  PMID: 23846567  (Epub July 2013)
#
#                                          Publisher  \
# 0                                              CUP
# 1                                              ACS
# 2                                              ACS
# 3                                              ACS
# 4                                              ACS
# 5                                              ACS
# 6                                              ACS
# 7                                              ACS
# 8     ACS (Amercian Chemical Society) Publications
# 9     ACS (Amercian Chemical Society) Publications
# 10    ACS (Amercian Chemical Society) Publications
# 11    ACS (Amercian Chemical Society) Publications
# 12    ACS (Amercian Chemical Society) Publications
# 13                                ACS Publications
# 14                                ACS Publications
# 15                                   AGA Institute
# 16                                           AMBSB
# 17           American Association of Immunologists
# 18           American Association of Immunologists
# 19                       American Chemical Society
# 20                       American Chemical Society
# 21                       American Chemical Society
# 22                       American Chemical Society
# 23                       AMERICAN CHEMICAL SOCIETY
# 24                       American Chemical Society
# 25                       American Chemical Society
# 26                       American Chemical Society
# 27                       American Chemical Society
# 28                       American Chemical Society
# 29                       American Chemical Society
# ...                                            ...
# 2097                               Wiley-Blackwell
# 2098                               Wiley-Blackwell
# 2099                               Wiley-Blackwell
# 2100                               Wiley-Blackwell
# 2101                               Wiley-Blackwell
# 2102                               Wiley-Blackwell
# 2103                               Wiley-Blackwell
# 2104                               Wiley-Blackwell
# 2105                               Wiley-Blackwell
# 2106                               Wiley-Blackwell
# 2107            Wiley-Blackwell, John Wiley & Sons
# 2108                                     Wiley-VCH
# 2109                                     Wiley-VCH
# 2110                                     Wiley-VCH
# 2111                                     Wiley-VCH
# 2112                                     Wiley-VCH
# 2113                                     Wiley-VCH
# 2114                               Wliey-Blackwell
# 2115                                Wolters Kluwer
# 2116                                Wolters Kluwer
# 2117                                Wolters Kluwer
# 2118                                Wolters Kluwer
# 2119                                Wolters Kluwer
# 2120                                Wolters Kluwer
# 2121                                Wolters Kluwer
# 2122                         Wolters Kluwer Health
# 2123                        Wolters Kluwer Health
# 2124                        Wolters Kluwer Health
# 2125                 Wolters Kluwer N.V./Lippinott
# 2126                               Wolters Kluwers
#
#                                           Journal title  \
# 0                                psychological medicine
# 1                                     biomacromolecules
# 2                                            j med chem
# 3                                            j med chem
# 4                                            j org chem
# 5                        journal of medicinal chemistry
# 6                          journal of proteome research
# 7                                             mol pharm
# 8                                  acs chemical biology
# 9                                  acs chemical biology
# 10         journal of chemical information and modeling
# 11                       journal of medicinal chemistry
# 12                       journal of medicinal chemistry
# 13                                         biochemistry
# 14                       journal of medicinal chemistry
# 15                                     gastroenterology
# 16                      journal of biological chemistry
# 17                                journal of immunology
# 18                                journal of immunology
# 19                                 acs chemical biology
# 20                                 acs chemical biology
# 21                                 acs chemical biology
# 22                            acs chemical neuroscience
# 23                                             acs nano
# 24                            american chemical society
# 25                                 analytical chemistry
# 26                                 analytical chemistry
# 27                                 analytical chemistry
# 28                               bioconjugate chemistry
# 29                       journal of medicinal chemistry
# ...                                                 ...
# 2097                             molecular microbiology
# 2098                                    obesity reviews
# 2099                                    obesity reviews
# 2100                             statistics in medicine
# 2101                                         stem cells
# 2102                                            synapse
# 2103               the european journal of neuroscience
# 2104                                            traffic
# 2105                                            traffic
# 2106                         zoonoses and public health
# 2107                american journal of transplantation
# 2108                                 angew chems int ed
# 2109                                        chembiochem
# 2110                                        chemmedchem
# 2111                                        chemmedchem
# 2112                                        chemmedchem
# 2113                                          protemics
# 2114                   journal of small animal practice
# 2115                                               aids
# 2116                                       aids journal
# 2117                                            aids uk
# 2118                                            aids uk
# 2119  jaids journal of acquired immune deficiency sy...
# 2120  journal of acquired immune deficiency syndroms...
# 2121                                    journal of aids
# 2122                               circulation research
# 2123                                               aids
# 2124                               pediatr infect dis j
# 2125                                               aids
# 2126    journal of acquired immune deficiency syndromes
#
#                                           Article title  \
# 0     Reduced parahippocampal cortical thickness in ...
# 1     Structural characterization of a Model Gram-ne...
# 2     Fumaroylamino-4,5-epoxymorphinans and related ...
# 3     Orvinols with mixed kappa/mu opioid receptor a...
# 4     Regioselective opening of myo-inositol orthoes...
# 5     Comparative Structural and Functional Studies ...
# 6     Mapping Proteolytic Processing in the Secretom...
# 7     Quantitative silencing of EGFP reporter gene b...
# 8     A Novel Allosteric Inhibitor of the Uridine Di...
# 9     Chemical proteomic analysis reveals the drugab...
# 10    Locating Sweet Spots for Screening Hits and Ev...
# 11    Synthesis and evaluation of ?-thymidine analog...
# 12    Discovery and structure-activity relationships...
# 13    Monomeric 14-3-3 has a chaperone-like activity...
# 14    Synthesis and in vitro and in vivo characteriz...
# 15    Much of the genetic risk of colorectal cancer ...
# 16                  Annexin-1 interaction with FPR2/ALX
# 17    Sialoadhesin ligand expression identifies a su...
# 18    Regulation of Foxp3+ Inducible Regulatory T Ce...
# 19    Discovery of an allosteric inhibitor binding s...
# 20    Synthesis of alpha-glucan in mycobacteria invo...
# 21    Discovery of ?2 Adrenergic Receptor Ligands Us...
# 22    Continuous online microdialysis using microflu...
# 23    HYDROXY-TERMINATED CONJUGATED POLYMER NANOPART...
# 24    Characterizing the Fatty Acid Binding Site in ...
# 25    Amphipathic polymers facilitate the study of f...
# 26    Quantitative dynamics of phosphorproteome: the...
# 27    Variable-Pitch Rectangular Cross-section Radio...
# 28    Design, synthesis and functional activity of l...
# 29    Toward biophysical probes for the 5-HT3 recept...
# ...                                                 ...
# 2097  Shigella IpaD has a Dual Role: Signal Transduc...
# 2098  Does maternal body mass index during pregnancy...
# 2099  Obesity and socioeconomic status in developing...
# 2100  Combining multiple imputation and meta-analysi...
# 2101  Matrix remodelling maintains ESC self-renewal ...
# 2102  Presynaptic pH and vesicle fusion in Drosophil...
# 2103  Hyperpolarization-activated ion channels as ta...
# 2104  Efficient internalization of MHC I requires ly...
# 2105  Proteomic analysis of clathrin interactions in...
# 2106  Ecology of zoonotic infectious diseases in bat...
# 2107  Low dose rapamycin treatment increases the abi...
# 2108  Design and synthesis of cyclic ADP-4-thioribos...
# 2109  A Prototypical Small-Molecule Modulator Uncoup...
# 2110  Structure-Activity Relationship Studies of Pyr...
# 2111  From On-Target to Off-Target Activity: Identif...
# 2112  Synthesis and structure-activity relationship ...
# 2113  Carbon source-induced reprogramming of the cel...
# 2114  Prevalence, outcome and risk factors for post-...
# 2115  HIV infected adolescents in Southern Africa ca...
# 2116  Short title: TB and VL breakthrough and failur...
# 2117   Sexual behaviour in a rural high HIV prevalence
# 2118  HIV incidence and survival from age-specific s...
# 2119  Accelerated biological ageing in HIV-infected ...
# 2120  Reduction in early mortality on antiretroviral...
# 2121  Risk factors for seropositivity to Kaposi sarc...
# 2122  Mechanistic Links Between Na+ Channel (SCN5A) ...
# 2123  Evaluation of an empiric risk screening score ...
# 2124  Topical umbilical cord care for prevention of ...
# 2125  Grassroots Community Organisations' Contributi...
# 2126  A novel community health worker tool outperfor...
#
#      COST (£) charged to Wellcome (inc VAT when charged)  \
# 0                                                 £0.00
# 1                                              £2381.04
# 2                                               £642.56
# 3                                               £669.64
# 4                                               £685.88
# 5                                              £2392.20
# 6                                              £2367.95
# 7                                               £649.33
# 8                                              £1294.59
# 9                                              £1294.78
# 10                                             £1329.69
# 11                                             £1287.20
# 12                                             £1324.66
# 13                                              £665.64
# 14                                             £1006.72
# 15                                              £238.08
# 16                                              £265.67
# 17                                             £2035.00
# 18                                             £3108.08
# 19                                             £1267.76
# 20                                             £2286.73
# 21                                              £947.07
# 22                                             £1186.80
# 23                                              £642.89
# 24                                             £1533.29
# 25                                             £2082.74
# 26                                             £2314.10
# 27                                              £759.67
# 28                                             £1565.26
# 29                                              £572.74
# ...                                                 ...
# 2097                                           £2236.02
# 2098                                           £2275.02
# 2099                                           £2373.57
# 2100                                            £791.19
# 2101                                           £1551.49
# 2102                                           £1961.68
# 2103                                           £1982.35
# 2104                                           £2239.22
# 2105                                           £2377.65
# 2106                                           £2272.15
# 2107                                           £1900.70
# 2108                                           £3026.17
# 2109                                           £1851.15
# 2110                                           £1812.89
# 2111                                           £1816.70
# 2112                                           £2168.05
# 2113                                           £1409.96
# 2114                                           £2400.00
# 2115                                           £1968.63
# 2116                                           £2015.72
# 2117                                           £1836.92
# 2118                                           £1836.92
# 2119                                           £1375.80
# 2120                                           £1836.92
# 2121                                           £2009.65
# 2122                                           £1334.15
# 2123                                           £1834.77
# 2124                                           £1834.77
# 2125                                           £2374.52
# 2126                                           £2034.75
#
#                             cleansed_journal_title
# 0                           psychological medicine
# 1                                biomacromolecules
# 2                      journal medicinal chemistry
# 3                      journal medicinal chemistry
# 4                        journal organic chemistry
# 5                   journal of medicinal chemistry
# 6                     journal of proteome research
# 7                           molecular pharmacology
# 8                             acs chemical biology
# 9                             acs chemical biology
# 10    journal of chemical information and modeling
# 11                  journal of medicinal chemistry
# 12                  journal of medicinal chemistry
# 13                                    biochemistry
# 14                  journal of medicinal chemistry
# 15                                gastroenterology
# 16                 journal of biological chemistry
# 17                           journal of immunology
# 18                           journal of immunology
# 19                            acs chemical biology
# 20                            acs chemical biology
# 21                            acs chemical biology
# 22                       acs chemical neuroscience
# 23                                        acs nano
# 24                       american chemical society
# 25                            analytical chemistry
# 26                            analytical chemistry
# 27                            analytical chemistry
# 28                          bioconjugate chemistry
# 29                  journal of medicinal chemistry
# ...                                            ...
# 2097                        molecular microbiology
# 2098                               obesity reviews
# 2099                               obesity reviews
# 2100                        statistics in medicine
# 2101                                    stem cells
# 2102                                       synapse
# 2103          the european journal of neuroscience
# 2104                                       traffic
# 2105                                       traffic
# 2106                    zoonoses and public health
# 2107           american journal of transplantation
# 2108                            angew chems int ed
# 2109                                   chembiochem
# 2110                                   chemmedchem
# 2111                                   chemmedchem
# 2112                                   chemmedchem
# 2113                                     protemics
# 2114              journal of small animal practice
# 2115                                          aids
# 2116                                  aids journal
# 2117                                       aids uk
# 2118                                       aids uk
# 2119                                         jaids
# 2120                                         jaids
# 2121                               journal of aids
# 2122                          circulation research
# 2123                                          aids
# 2124                  pediatr infectious disease j
# 2125                                          aids
# 2126                                         jaids
#
# [2127 rows x 6 columns]

# %%
#get every combination of unique journal titles (as strings) and put into a dataframe

combos = pd.DataFrame(list(combinations(wt['cleansed_journal_title'].unique().astype(str),2)), columns=['title1','title2'])
combos.describe()
# Out:
#                         title1                        title2
# count                   365085                        365085
# unique                     854                           854
# top     psychological medicine  pediatr infectious disease j
# freq                       854                           854

# %%
def fuzz_ratio_ignore(s1, s2):
    # use this to manually ignore and include some combos. Can go further with this with more time.
    combos_to_ignore = [
        {'acta crystallographica d', 'acta crystallographica f'},
        {'analytical chemistry', 'analytical biochemistry'},
        {'journal of medical ethics', 'journal of medical genetics'},
        {'international journal of cardiology', 'international journal of parasitology'},
        {'british journal of haematology', 'british journal of pharmacology'}
    ]
    
    combos_to_include = [
        {'lancet','the lancet'}
    ]
    
    for combo in combos_to_ignore:
        if s1 in combo and s2 in combo:
            return 0
    for combo in combos_to_include:
        if s1 in combo and s2 in combo:
            return 100
    return fuzz.ratio(s1, s2)

# %%
# give a fuzz ratio to every combo of journal titles
combos['fuzz_ratio'] = combos.apply(lambda s: fuzz_ratio_ignore(s['title1'], s['title2']), axis=1)
combos.head()
# Out:
#                    title1                          title2  fuzz_ratio
# 0  psychological medicine               biomacromolecules          36
# 1  psychological medicine     journal medicinal chemistry          49
# 2  psychological medicine       journal organic chemistry          38
# 3  psychological medicine  journal of medicinal chemistry          46
# 4  psychological medicine    journal of proteome research          28

# %%
##### find the highest fuzz ratio level where a combo is not the same journal
combos[combos['fuzz_ratio']==91]

# the faseb journal and the febs journal are different journals
# Journal title pairings with a fuzz ratio above 91 refer to the same journal
# Out:
#                                       title1  \
# 10358                  journal of immunology
# 18156                  journal of physiology
# 18988         the journal of neurophysiology
# 19563         american journal of psychiatry
# 93067               journal of endocrinology
# 254349                     the faseb journal
# 274134                acta crystallography d
# 279068  american journal of medical genetics
# 279596              the journal of pathology
#
#                                              title2  fuzz_ratio
# 10358                     the journal of immunology          91
# 18156                     the journal of physiology          91
# 18988                     the journal of physiology          91
# 19563                   asian journal of psychiatry          91
# 93067                 journal of neuroendocrinology          91
# 254349                             the febs journal          91
# 274134                     acta crystallographica d          91
# 279068  american journal of medical genetics part a          91
# 279596                         journal of pathology          91

# %%
def unique_strings_list(series):
    return list(series.dropna().unique().astype(str))

def fuzz_groups(usl, auto_accept_fuzz_ratio):
    ''' Takes a unique strings list and a minimum fuzz ratio, returns groups of strings as list of lists.
    Within each group, fuzz.ratio(s1, s2) returns a number that is at least the min_fuzz_ratio when passed the first string of the group and any other string '''
    
    groups = [] # groups of like strings list
    
    '''For each string in usl (s1), find its fuzzy ratio with all the remaining strings (s2) below it . 
    If a match is found (high enough fuzzy ratio) and it is the first match found, 
        append a new list inside the groups list containing both strings (s1 and s2)
    If a match is found and it is not the first match, 
        append only the second string (s2) to the list that already contains the first journal title (which will be the list at groups[-1])
    Remove every matched string from usl (by changing value to None)'''
    
    for s1 in usl: 
        match = False
        for s2 in usl[usl.index(s1)+1:]:
            
            #if match is found (fuzz.ratio(s1, s2) is at least the auto_accept_fuzz_ratio)
            if fuzz_ratio_ignore(s1, s2) >= auto_accept_fuzz_ratio: 
                
                if not match: #if first match, append new list containing s1 to groups
                    groups.append([s1])
                    
                match = True
                groups[-1].append(s2) # append s2 to group list
                usl[usl.index(s2)] = None #s2 matched so remove it from usl list
                
        if match == True: #remove s1 from usl list if it had a match
            usl[usl.index(s1)] = None
    
    usl_remaining = [i for i in usl if i]
    return groups, usl_remaining

# %%
usl = unique_strings_list(wt['cleansed_journal_title'])

journal_groups, _ = fuzz_groups(usl, 92)

journal_groups
# Out:
# [['psychological medicine', 'pyschological medicine'],
#  ['journal medicinal chemistry', 'journal of medicinal chemistry'],
#  ['journal of biological chemistry',
#   'journal biological chemistry',
#   'the journal of biological chemistry'],
#  ['journal of immunology', 'journal immunology'],
#  ['journal of neurophysiology', 'the journal of neurophysiology'],
#  ['american journal of psychiatry', 'americal journal of psychiatry'],
#  ['antimicrobial agents and chemotherapy',
#   'antimicrobial agfents and chemotherapy',
#   'antimicobial agents and chemotherapy'],
#  ['journal of clinical microbiology', 'jounral of clinical microbiology'],
#  ['the american journal of human genetics',
#   'american journal of human genetics',
#   'the americal journal of human genetics'],
#  ['biological chemistry', 'biologicial chemistry'],
#  ['mcp  molecular and cellular proteomics',
#   'molecular and cellular proteomics'],
#  ['biochemical journal', 'biochemical journals'],
#  ['bmc  public health', 'bmc public health'],
#  ['bmc genomics', 'bms genomics'],
#  ['international journal of behavioral nutrition and physical activity',
#   'international journal of behavioural nutrition and physical activity'],
#  ['british journal of ophthalmology', 'british journal of opthalmology'],
#  ['journal of neuroscience', 'the journal of neuroscience'],
#  ['parasitology', 'parsitology'],
#  ['british journal for the history of science',
#   'british journal of the history of science'],
#  ['journal of cell science', 'journal cell science'],
#  ['developmental cell', 'development cell'],
#  ['american journal for clinical nutrition',
#   'american journal of clinical nutrition'],
#  ['behavior research and therapy', 'behaviour research and therapy'],
#  ['biochimica et bioohysica acta   molecular basis of disease',
#   'biochimica et biophysica acta   molecular basis of disease'],
#  ['current opinion in neurobiology', 'current opinions in neurobiology'],
#  ['international journal for parasitology',
#   'international journal of parasitology'],
#  ['international journal of biochemistry and cell biology',
#   'the international journal of biochemistry and cell biology'],
#  ['journal molecular biology', 'journal of molecular biology'],
#  ['journal of behavior therapy and experimental psychiatry',
#   'journal of behaviour therapy and experimental psychiatry'],
#  ['journal of hepatology', 'journal of pathology'],
#  ['lancet', 'the lancet'],
#  ['molecluar and cellular endocrinology',
#   'molecular and cellular endocrinology'],
#  ['trends in neuroscience', 'trends in neurosciences'],
#  ['acta crystallographicad  biological crystallography',
#   'acta crystallographicad   biological crystallography'],
#  ['acta crystallographicad',
#   'acta crystallographica d',
#   'acta crystallographica f'],
#  ['genetic epidemiology', 'genetic epidemology'],
#  ['european journal of immunology', 'european journal immunology'],
#  ['development science', 'developmental science'],
#  ['heptology', 'hepatology'],
#  ['journal of visualized experiments',
#   'journal of visualized experiements',
#   'journal of visulaized expermiments',
#   'the journal of visualized experiments'],
#  ['epigenetics', 'epigentics'],
#  ['journal of cognitive neuroscience',
#   'the journal of cognitive neuroscience'],
#  ['cell death and differentiation', 'cell death differentiation'],
#  ['journal of investigative dermatology',
#   'the journal of investigative dermatology'],
#  ['american journal epidemiology', 'american journal of epidemiology'],
#  ['clinical infectious diseases', 'clinicla infectious disease'],
#  ['international joural of epidemiology',
#   'international journal of epidemiology',
#   'inyernational journal of epidemiology'],
#  ['journal of infectious diseases',
#   'the journal of infectious diseases',
#   'journal infectious disease'],
#  ['nucleic acids research', 'nucleic acid research'],
#  ['molecular biology and evolution', 'molecular biological and evolution'],
#  ['biinformatics', 'bioinformatics'],
#  ['nephrology dialysis and transplantation',
#   'nephrology dialysis transplantation'],
#  ['plos computational biology', 'plos  computational biology'],
#  ['plos one', 'plos  one'],
#  ['plos negected tropical diseases', 'plos neglected tropical diseases'],
#  ['british journal of psychiatry',
#   'britsh journal of psychiatry',
#   'the british journal of psychiatry'],
#  ['journal of the royal society interface',
#   'journal of the royal society  interface'],
#  ['proceedings of royal society', 'proceedings of the royal society'],
#  ['cellular and molecular cell sciences',
#   'cellular and molecular life sciences'],
#  ['european child and adolescent psychiatry',
#   'european child and adolescent psychiatty'],
#  ['journal of autism and development disorders',
#   'journal of autism and developmental disorders'],
#  ['pflugers archiv', 'pflugers archive'],
#  ['social psychiatry and psychiatric epidemiology',
#   'social psychiatry and psychiatric epidemiol'],
#  ['journal of clinical endocrinology', 'journal od clinical endocrinology'],
#  ['angewande chemie', 'angewandte chemie'],
#  ['british journal of dermatology', 'british journal of haematology'],
#  ['british journal of pharmacology', 'british jounal of pharmacology'],
#  ['european journal of neuroscience', 'the european journal of neuroscience'],
#  ['child  care  health development', 'child  care  heath and development']]

# %%
def spell_check(s):
    spelling = True
    h = Hunspell()
    for word in s.split():
        if not ((h.spell(word)) or h.spell(word.title())or h.spell(word.upper())):
            spelling = False
    return spelling

# %%
title_cleanse_dict = {}
for group in journal_groups:
    spelling = False
    for title in group:
        if spell_check(title):
            title_cleanse_dict.update({d_title: title for d_title in group})
            spelling = True
    if not spelling:
        title_cleanse_dict.update({d_title: group[0] for d_title in group})
                                  
title_cleanse_dict
# Out:
# {'psychological medicine': 'psychological medicine',
#  'pyschological medicine': 'psychological medicine',
#  'journal medicinal chemistry': 'journal of medicinal chemistry',
#  'journal of medicinal chemistry': 'journal of medicinal chemistry',
#  'journal of biological chemistry': 'the journal of biological chemistry',
#  'journal biological chemistry': 'the journal of biological chemistry',
#  'the journal of biological chemistry': 'the journal of biological chemistry',
#  'journal of immunology': 'journal immunology',
#  'journal immunology': 'journal immunology',
#  'journal of neurophysiology': 'the journal of neurophysiology',
#  'the journal of neurophysiology': 'the journal of neurophysiology',
#  'american journal of psychiatry': 'american journal of psychiatry',
#  'americal journal of psychiatry': 'american journal of psychiatry',
#  'antimicrobial agents and chemotherapy': 'antimicrobial agents and chemotherapy',
#  'antimicrobial agfents and chemotherapy': 'antimicrobial agents and chemotherapy',
#  'antimicobial agents and chemotherapy': 'antimicrobial agents and chemotherapy',
#  'journal of clinical microbiology': 'journal of clinical microbiology',
#  'jounral of clinical microbiology': 'journal of clinical microbiology',
#  'the american journal of human genetics': 'american journal of human genetics',
#  'american journal of human genetics': 'american journal of human genetics',
#  'the americal journal of human genetics': 'american journal of human genetics',
#  'biological chemistry': 'biological chemistry',
#  'biologicial chemistry': 'biological chemistry',
#  'mcp  molecular and cellular proteomics': 'mcp  molecular and cellular proteomics',
#  'molecular and cellular proteomics': 'mcp  molecular and cellular proteomics',
#  'biochemical journal': 'biochemical journals',
#  'biochemical journals': 'biochemical journals',
#  'bmc  public health': 'bmc  public health',
#  'bmc public health': 'bmc  public health',
#  'bmc genomics': 'bmc genomics',
#  'bms genomics': 'bmc genomics',
#  'international journal of behavioral nutrition and physical activity': 'international journal of behavioral nutrition and physical activity',
#  'international journal of behavioural nutrition and physical activity': 'international journal of behavioral nutrition and physical activity',
#  'british journal of ophthalmology': 'british journal of opthalmology',
#  'british journal of opthalmology': 'british journal of opthalmology',
#  'journal of neuroscience': 'journal of neuroscience',
#  'the journal of neuroscience': 'journal of neuroscience',
#  'parasitology': 'parasitology',
#  'parsitology': 'parasitology',
#  'british journal for the history of science': 'british journal of the history of science',
#  'british journal of the history of science': 'british journal of the history of science',
#  'journal of cell science': 'journal cell science',
#  'journal cell science': 'journal cell science',
#  'developmental cell': 'development cell',
#  'development cell': 'development cell',
#  'american journal for clinical nutrition': 'american journal of clinical nutrition',
#  'american journal of clinical nutrition': 'american journal of clinical nutrition',
#  'behavior research and therapy': 'behavior research and therapy',
#  'behaviour research and therapy': 'behavior research and therapy',
#  'biochimica et bioohysica acta   molecular basis of disease': 'biochimica et bioohysica acta   molecular basis of disease',
#  'biochimica et biophysica acta   molecular basis of disease': 'biochimica et bioohysica acta   molecular basis of disease',
#  'current opinion in neurobiology': 'current opinions in neurobiology',
#  'current opinions in neurobiology': 'current opinions in neurobiology',
#  'international journal for parasitology': 'international journal of parasitology',
#  'international journal of parasitology': 'international journal of parasitology',
#  'international journal of biochemistry and cell biology': 'the international journal of biochemistry and cell biology',
#  'the international journal of biochemistry and cell biology': 'the international journal of biochemistry and cell biology',
#  'journal molecular biology': 'journal of molecular biology',
#  'journal of molecular biology': 'journal of molecular biology',
#  'journal of behavior therapy and experimental psychiatry': 'journal of behavior therapy and experimental psychiatry',
#  'journal of behaviour therapy and experimental psychiatry': 'journal of behavior therapy and experimental psychiatry',
#  'journal of hepatology': 'journal of pathology',
#  'journal of pathology': 'journal of pathology',
#  'lancet': 'the lancet',
#  'the lancet': 'the lancet',
#  'molecluar and cellular endocrinology': 'molecular and cellular endocrinology',
#  'molecular and cellular endocrinology': 'molecular and cellular endocrinology',
#  'trends in neuroscience': 'trends in neuroscience',
#  'trends in neurosciences': 'trends in neuroscience',
#  'acta crystallographicad  biological crystallography': 'acta crystallographicad  biological crystallography',
#  'acta crystallographicad   biological crystallography': 'acta crystallographicad  biological crystallography',
#  'acta crystallographicad': 'acta crystallographicad',
#  'acta crystallographica d': 'acta crystallographicad',
#  'acta crystallographica f': 'acta crystallographicad',
#  'genetic epidemiology': 'genetic epidemiology',
#  'genetic epidemology': 'genetic epidemiology',
#  'european journal of immunology': 'european journal immunology',
#  'european journal immunology': 'european journal immunology',
#  'development science': 'developmental science',
#  'developmental science': 'developmental science',
#  'heptology': 'heptology',
#  'hepatology': 'heptology',
#  'journal of visualized experiments': 'the journal of visualized experiments',
#  'journal of visualized experiements': 'the journal of visualized experiments',
#  'journal of visulaized expermiments': 'the journal of visualized experiments',
#  'the journal of visualized experiments': 'the journal of visualized experiments',
#  'epigenetics': 'epigenetics',
#  'epigentics': 'epigenetics',
#  'journal of cognitive neuroscience': 'journal of cognitive neuroscience',
#  'the journal of cognitive neuroscience': 'journal of cognitive neuroscience',
#  'cell death and differentiation': 'cell death differentiation',
#  'cell death differentiation': 'cell death differentiation',
#  'journal of investigative dermatology': 'the journal of investigative dermatology',
#  'the journal of investigative dermatology': 'the journal of investigative dermatology',
#  'american journal epidemiology': 'american journal of epidemiology',
#  'american journal of epidemiology': 'american journal of epidemiology',
#  'clinical infectious diseases': 'clinical infectious diseases',
#  'clinicla infectious disease': 'clinical infectious diseases',
#  'international joural of epidemiology': 'international journal of epidemiology',
#  'international journal of epidemiology': 'international journal of epidemiology',
#  'inyernational journal of epidemiology': 'international journal of epidemiology',
#  'journal of infectious diseases': 'journal infectious disease',
#  'the journal of infectious diseases': 'journal infectious disease',
#  'journal infectious disease': 'journal infectious disease',
#  'nucleic acids research': 'nucleic acid research',
#  'nucleic acid research': 'nucleic acid research',
#  'molecular biology and evolution': 'molecular biological and evolution',
#  'molecular biological and evolution': 'molecular biological and evolution',
#  'biinformatics': 'biinformatics',
#  'bioinformatics': 'biinformatics',
#  'nephrology dialysis and transplantation': 'nephrology dialysis and transplantation',
#  'nephrology dialysis transplantation': 'nephrology dialysis and transplantation',
#  'plos computational biology': 'plos computational biology',
#  'plos  computational biology': 'plos computational biology',
#  'plos one': 'plos one',
#  'plos  one': 'plos one',
#  'plos negected tropical diseases': 'plos negected tropical diseases',
#  'plos neglected tropical diseases': 'plos negected tropical diseases',
#  'british journal of psychiatry': 'the british journal of psychiatry',
#  'britsh journal of psychiatry': 'the british journal of psychiatry',
#  'the british journal of psychiatry': 'the british journal of psychiatry',
#  'journal of the royal society interface': 'journal of the royal society  interface',
#  'journal of the royal society  interface': 'journal of the royal society  interface',
#  'proceedings of royal society': 'proceedings of the royal society',
#  'proceedings of the royal society': 'proceedings of the royal society',
#  'cellular and molecular cell sciences': 'cellular and molecular life sciences',
#  'cellular and molecular life sciences': 'cellular and molecular life sciences',
#  'european child and adolescent psychiatry': 'european child and adolescent psychiatry',
#  'european child and adolescent psychiatty': 'european child and adolescent psychiatry',
#  'journal of autism and development disorders': 'journal of autism and developmental disorders',
#  'journal of autism and developmental disorders': 'journal of autism and developmental disorders',
#  'pflugers archiv': 'pflugers archiv',
#  'pflugers archive': 'pflugers archiv',
#  'social psychiatry and psychiatric epidemiology': 'social psychiatry and psychiatric epidemiology',
#  'social psychiatry and psychiatric epidemiol': 'social psychiatry and psychiatric epidemiology',
#  'journal of clinical endocrinology': 'journal od clinical endocrinology',
#  'journal od clinical endocrinology': 'journal od clinical endocrinology',
#  'angewande chemie': 'angewande chemie',
#  'angewandte chemie': 'angewande chemie',
#  'british journal of dermatology': 'british journal of dermatology',
#  'british journal of haematology': 'british journal of dermatology',
#  'british journal of pharmacology': 'british journal of pharmacology',
#  'british jounal of pharmacology': 'british journal of pharmacology',
#  'european journal of neuroscience': 'european journal of neuroscience',
#  'the european journal of neuroscience': 'european journal of neuroscience',
#  'child  care  health development': 'child  care  heath and development',
#  'child  care  heath and development': 'child  care  heath and development'}

# %%
wt['cleansed_journal_title'] = wt['cleansed_journal_title'].apply(lambda x: title_cleanse_dict.get(x, x))
wt
# Out:
#                             PMID/PMCID  \
# 0                                  NaN
# 1                           PMC3679557
# 2                23043264  PMC3506128
# 3                  23438330 PMC3646402
# 4                 23438216 PMC3601604
# 5                           PMC3579457
# 6                           PMC3709265
# 7                 23057412 PMC3495574
# 8                    PMCID: PMC3780468
# 9                    PMCID: PMC3621575
# 10                   PMCID: PMC3739413
# 11                   PMCID: PMC3530961
# 12                   PMCID: PMC3624797
# 13                          PMC3413243
# 14                          PMC3694353
# 15                          PMC3572711
# 16                            22610094
# 17                   PMCID: PMC3586974
# 18        23455506  PMCID: PMC3607399
# 19          PMID: 24015914 PMC3833349
# 20                       : PMC3805332
# 21                                 NaN
# 22            PMCID:\n    PMC3656742\n
# 23                      PMCID: 3584654
# 24                 22971149 PMC3466778
# 25                            23072351
# 26                          PMC3477822
# 27                          PMC3530960
# 28                23458425 PMC3630740
# 29                      PMID: 20146481
# ...                                ...
# 2097                           3575693
# 2098        PMID: 22188548 PMC3492912
# 2099        PMID: 22764734 PMC3798095
# 2100                    PMID: 23703895
# 2101                 PMCID: PMC3664106
# 2102                    PMID: 23649934
# 2103                        PMC2955965
# 2104        PMID: 19948006 PMC3551259
# 2105                    PMID: 23305527
# 2106                 PMCID: PMC3600532
# 2107                        PMC3440570
# 2108              23670821 PMC3738939
# 2109                          23640856
# 2110                    PMID: 23918316
# 2111                 PMCID: PMC3728731
# 2112       23495205685.88 PMC3743159
# 2113         PMID:22997008 PMC3569869
# 2114                           3708104
# 2115                        PMC3713766
# 2116                        PMC3819359
# 2117                       PMC3773237
# 2118                       PMC3815011
# 2119                        PMC3805356
# 2120                             Epub
# 2121                        PMC3707567
# 2122                           2901593
# 2123                           3748854
# 2124                           3785148
# 2125          PMCID:\n    PMC3647051\n
# 2126  PMID: 23846567  (Epub July 2013)
#
#                                          Publisher  \
# 0                                              CUP
# 1                                              ACS
# 2                                              ACS
# 3                                              ACS
# 4                                              ACS
# 5                                              ACS
# 6                                              ACS
# 7                                              ACS
# 8     ACS (Amercian Chemical Society) Publications
# 9     ACS (Amercian Chemical Society) Publications
# 10    ACS (Amercian Chemical Society) Publications
# 11    ACS (Amercian Chemical Society) Publications
# 12    ACS (Amercian Chemical Society) Publications
# 13                                ACS Publications
# 14                                ACS Publications
# 15                                   AGA Institute
# 16                                           AMBSB
# 17           American Association of Immunologists
# 18           American Association of Immunologists
# 19                       American Chemical Society
# 20                       American Chemical Society
# 21                       American Chemical Society
# 22                       American Chemical Society
# 23                       AMERICAN CHEMICAL SOCIETY
# 24                       American Chemical Society
# 25                       American Chemical Society
# 26                       American Chemical Society
# 27                       American Chemical Society
# 28                       American Chemical Society
# 29                       American Chemical Society
# ...                                            ...
# 2097                               Wiley-Blackwell
# 2098                               Wiley-Blackwell
# 2099                               Wiley-Blackwell
# 2100                               Wiley-Blackwell
# 2101                               Wiley-Blackwell
# 2102                               Wiley-Blackwell
# 2103                               Wiley-Blackwell
# 2104                               Wiley-Blackwell
# 2105                               Wiley-Blackwell
# 2106                               Wiley-Blackwell
# 2107            Wiley-Blackwell, John Wiley & Sons
# 2108                                     Wiley-VCH
# 2109                                     Wiley-VCH
# 2110                                     Wiley-VCH
# 2111                                     Wiley-VCH
# 2112                                     Wiley-VCH
# 2113                                     Wiley-VCH
# 2114                               Wliey-Blackwell
# 2115                                Wolters Kluwer
# 2116                                Wolters Kluwer
# 2117                                Wolters Kluwer
# 2118                                Wolters Kluwer
# 2119                                Wolters Kluwer
# 2120                                Wolters Kluwer
# 2121                                Wolters Kluwer
# 2122                         Wolters Kluwer Health
# 2123                        Wolters Kluwer Health
# 2124                        Wolters Kluwer Health
# 2125                 Wolters Kluwer N.V./Lippinott
# 2126                               Wolters Kluwers
#
#                                           Journal title  \
# 0                                psychological medicine
# 1                                     biomacromolecules
# 2                                            j med chem
# 3                                            j med chem
# 4                                            j org chem
# 5                        journal of medicinal chemistry
# 6                          journal of proteome research
# 7                                             mol pharm
# 8                                  acs chemical biology
# 9                                  acs chemical biology
# 10         journal of chemical information and modeling
# 11                       journal of medicinal chemistry
# 12                       journal of medicinal chemistry
# 13                                         biochemistry
# 14                       journal of medicinal chemistry
# 15                                     gastroenterology
# 16                      journal of biological chemistry
# 17                                journal of immunology
# 18                                journal of immunology
# 19                                 acs chemical biology
# 20                                 acs chemical biology
# 21                                 acs chemical biology
# 22                            acs chemical neuroscience
# 23                                             acs nano
# 24                            american chemical society
# 25                                 analytical chemistry
# 26                                 analytical chemistry
# 27                                 analytical chemistry
# 28                               bioconjugate chemistry
# 29                       journal of medicinal chemistry
# ...                                                 ...
# 2097                             molecular microbiology
# 2098                                    obesity reviews
# 2099                                    obesity reviews
# 2100                             statistics in medicine
# 2101                                         stem cells
# 2102                                            synapse
# 2103               the european journal of neuroscience
# 2104                                            traffic
# 2105                                            traffic
# 2106                         zoonoses and public health
# 2107                american journal of transplantation
# 2108                                 angew chems int ed
# 2109                                        chembiochem
# 2110                                        chemmedchem
# 2111                                        chemmedchem
# 2112                                        chemmedchem
# 2113                                          protemics
# 2114                   journal of small animal practice
# 2115                                               aids
# 2116                                       aids journal
# 2117                                            aids uk
# 2118                                            aids uk
# 2119  jaids journal of acquired immune deficiency sy...
# 2120  journal of acquired immune deficiency syndroms...
# 2121                                    journal of aids
# 2122                               circulation research
# 2123                                               aids
# 2124                               pediatr infect dis j
# 2125                                               aids
# 2126    journal of acquired immune deficiency syndromes
#
#                                           Article title  \
# 0     Reduced parahippocampal cortical thickness in ...
# 1     Structural characterization of a Model Gram-ne...
# 2     Fumaroylamino-4,5-epoxymorphinans and related ...
# 3     Orvinols with mixed kappa/mu opioid receptor a...
# 4     Regioselective opening of myo-inositol orthoes...
# 5     Comparative Structural and Functional Studies ...
# 6     Mapping Proteolytic Processing in the Secretom...
# 7     Quantitative silencing of EGFP reporter gene b...
# 8     A Novel Allosteric Inhibitor of the Uridine Di...
# 9     Chemical proteomic analysis reveals the drugab...
# 10    Locating Sweet Spots for Screening Hits and Ev...
# 11    Synthesis and evaluation of ?-thymidine analog...
# 12    Discovery and structure-activity relationships...
# 13    Monomeric 14-3-3 has a chaperone-like activity...
# 14    Synthesis and in vitro and in vivo characteriz...
# 15    Much of the genetic risk of colorectal cancer ...
# 16                  Annexin-1 interaction with FPR2/ALX
# 17    Sialoadhesin ligand expression identifies a su...
# 18    Regulation of Foxp3+ Inducible Regulatory T Ce...
# 19    Discovery of an allosteric inhibitor binding s...
# 20    Synthesis of alpha-glucan in mycobacteria invo...
# 21    Discovery of ?2 Adrenergic Receptor Ligands Us...
# 22    Continuous online microdialysis using microflu...
# 23    HYDROXY-TERMINATED CONJUGATED POLYMER NANOPART...
# 24    Characterizing the Fatty Acid Binding Site in ...
# 25    Amphipathic polymers facilitate the study of f...
# 26    Quantitative dynamics of phosphorproteome: the...
# 27    Variable-Pitch Rectangular Cross-section Radio...
# 28    Design, synthesis and functional activity of l...
# 29    Toward biophysical probes for the 5-HT3 recept...
# ...                                                 ...
# 2097  Shigella IpaD has a Dual Role: Signal Transduc...
# 2098  Does maternal body mass index during pregnancy...
# 2099  Obesity and socioeconomic status in developing...
# 2100  Combining multiple imputation and meta-analysi...
# 2101  Matrix remodelling maintains ESC self-renewal ...
# 2102  Presynaptic pH and vesicle fusion in Drosophil...
# 2103  Hyperpolarization-activated ion channels as ta...
# 2104  Efficient internalization of MHC I requires ly...
# 2105  Proteomic analysis of clathrin interactions in...
# 2106  Ecology of zoonotic infectious diseases in bat...
# 2107  Low dose rapamycin treatment increases the abi...
# 2108  Design and synthesis of cyclic ADP-4-thioribos...
# 2109  A Prototypical Small-Molecule Modulator Uncoup...
# 2110  Structure-Activity Relationship Studies of Pyr...
# 2111  From On-Target to Off-Target Activity: Identif...
# 2112  Synthesis and structure-activity relationship ...
# 2113  Carbon source-induced reprogramming of the cel...
# 2114  Prevalence, outcome and risk factors for post-...
# 2115  HIV infected adolescents in Southern Africa ca...
# 2116  Short title: TB and VL breakthrough and failur...
# 2117   Sexual behaviour in a rural high HIV prevalence
# 2118  HIV incidence and survival from age-specific s...
# 2119  Accelerated biological ageing in HIV-infected ...
# 2120  Reduction in early mortality on antiretroviral...
# 2121  Risk factors for seropositivity to Kaposi sarc...
# 2122  Mechanistic Links Between Na+ Channel (SCN5A) ...
# 2123  Evaluation of an empiric risk screening score ...
# 2124  Topical umbilical cord care for prevention of ...
# 2125  Grassroots Community Organisations' Contributi...
# 2126  A novel community health worker tool outperfor...
#
#      COST (£) charged to Wellcome (inc VAT when charged)  \
# 0                                                 £0.00
# 1                                              £2381.04
# 2                                               £642.56
# 3                                               £669.64
# 4                                               £685.88
# 5                                              £2392.20
# 6                                              £2367.95
# 7                                               £649.33
# 8                                              £1294.59
# 9                                              £1294.78
# 10                                             £1329.69
# 11                                             £1287.20
# 12                                             £1324.66
# 13                                              £665.64
# 14                                             £1006.72
# 15                                              £238.08
# 16                                              £265.67
# 17                                             £2035.00
# 18                                             £3108.08
# 19                                             £1267.76
# 20                                             £2286.73
# 21                                              £947.07
# 22                                             £1186.80
# 23                                              £642.89
# 24                                             £1533.29
# 25                                             £2082.74
# 26                                             £2314.10
# 27                                              £759.67
# 28                                             £1565.26
# 29                                              £572.74
# ...                                                 ...
# 2097                                           £2236.02
# 2098                                           £2275.02
# 2099                                           £2373.57
# 2100                                            £791.19
# 2101                                           £1551.49
# 2102                                           £1961.68
# 2103                                           £1982.35
# 2104                                           £2239.22
# 2105                                           £2377.65
# 2106                                           £2272.15
# 2107                                           £1900.70
# 2108                                           £3026.17
# 2109                                           £1851.15
# 2110                                           £1812.89
# 2111                                           £1816.70
# 2112                                           £2168.05
# 2113                                           £1409.96
# 2114                                           £2400.00
# 2115                                           £1968.63
# 2116                                           £2015.72
# 2117                                           £1836.92
# 2118                                           £1836.92
# 2119                                           £1375.80
# 2120                                           £1836.92
# 2121                                           £2009.65
# 2122                                           £1334.15
# 2123                                           £1834.77
# 2124                                           £1834.77
# 2125                                           £2374.52
# 2126                                           £2034.75
#
#                             cleansed_journal_title
# 0                           psychological medicine
# 1                                biomacromolecules
# 2                   journal of medicinal chemistry
# 3                   journal of medicinal chemistry
# 4                        journal organic chemistry
# 5                   journal of medicinal chemistry
# 6                     journal of proteome research
# 7                           molecular pharmacology
# 8                             acs chemical biology
# 9                             acs chemical biology
# 10    journal of chemical information and modeling
# 11                  journal of medicinal chemistry
# 12                  journal of medicinal chemistry
# 13                                    biochemistry
# 14                  journal of medicinal chemistry
# 15                                gastroenterology
# 16             the journal of biological chemistry
# 17                              journal immunology
# 18                              journal immunology
# 19                            acs chemical biology
# 20                            acs chemical biology
# 21                            acs chemical biology
# 22                       acs chemical neuroscience
# 23                                        acs nano
# 24                       american chemical society
# 25                            analytical chemistry
# 26                            analytical chemistry
# 27                            analytical chemistry
# 28                          bioconjugate chemistry
# 29                  journal of medicinal chemistry
# ...                                            ...
# 2097                        molecular microbiology
# 2098                               obesity reviews
# 2099                               obesity reviews
# 2100                        statistics in medicine
# 2101                                    stem cells
# 2102                                       synapse
# 2103              european journal of neuroscience
# 2104                                       traffic
# 2105                                       traffic
# 2106                    zoonoses and public health
# 2107           american journal of transplantation
# 2108                            angew chems int ed
# 2109                                   chembiochem
# 2110                                   chemmedchem
# 2111                                   chemmedchem
# 2112                                   chemmedchem
# 2113                                     protemics
# 2114              journal of small animal practice
# 2115                                          aids
# 2116                                  aids journal
# 2117                                       aids uk
# 2118                                       aids uk
# 2119                                         jaids
# 2120                                         jaids
# 2121                               journal of aids
# 2122                          circulation research
# 2123                                          aids
# 2124                  pediatr infectious disease j
# 2125                                          aids
# 2126                                         jaids
#
# [2127 rows x 6 columns]

# %% [markdown]
# # Make cost values usable

# %%
def clean_cost(s):
    cs = re.sub(r'[^0-9.]', '', s)
    cs = cs.strip()
    return float(cs)

# %%
wt['cleansed_cost'] = wt['COST (£) charged to Wellcome (inc VAT when charged)'].apply(clean_cost)

# %% [markdown]
# # 1. Determine the five most common journals and the total articles for each.

# %%
wt['cleansed_journal_title'].value_counts()
# Out:
# plos one                                               208
# the journal of biological chemistry                     71
# pnas                                                    39
# nucleic acid research                                   29
# neuroimage                                              29
# plos genetics                                           24
# plos pathogens                                          24
# plos negected tropical diseases                         21
# nature communications                                   19
# human molecular genetics                                19
# bmc  public health                                      15
# movement disorders                                      15
# journal of neuroscience                                 15
# brain                                                   14
# biochemical journals                                    14
# development cell                                        13
# journal of medicinal chemistry                          13
# journal of general virology                             11
# current biology                                         11
# plos computational biology                              10
# bmj                                                     10
# american journal of human genetics                      10
# malaria journal                                         10
# journal of virology                                     10
# european journal immunology                              9
# journal infectious disease                               9
# cell reports                                             9
# heptology                                                9
# development                                              9
# neuron                                                   9
#                                                       ...
# brt journal clinical pharmacology                        1
# emotion                                                  1
# neuromolecular medicine                                  1
# journal organic chemistry                                1
# journal of poverty and social justice                    1
# journal of microbiology                                  1
# pulmonary pharmacology and therapeutics                  1
# infection genetics and evolution                         1
# journal of hospital infections                           1
# chromosome research                                      1
# math biosci                                              1
# economic history review                                  1
# statistics in medicine                                   1
# international journal of health geographics              1
# frontiers in inflammation                                1
# nitric oxide                                             1
# acta opthalmologica                                      1
# molecular genetics and metabolism                        1
# visual neuroscience                                      1
# acta crystallography d                                   1
# frontiers in consciousness research                      1
# american chemical society                                1
# computational biology                                    1
# neuroinformatics                                         1
# anal bioanal chemistry                                   1
# pmedicine d one 2 03 one 30                              1
# hpb                                                      1
# environment and planning a                               1
# studies in history and philosophy of science part c      1
#                                                          1
# Name: cleansed_journal_title, Length: 777, dtype: int64

# %% [markdown]
# # 2. Calculate the mean, median, and standard deviation of the open-access cost per article for each journal

# %%
data = [] 
for journal in wt['cleansed_journal_title'].unique():
    name = journal
    mean = wt[wt['cleansed_journal_title']==journal].cleansed_cost.mean()
    median = wt[wt['cleansed_journal_title']==journal].cleansed_cost.median()
    stdev = wt[wt['cleansed_journal_title']==journal].cleansed_cost.std()
    
    data.append([name, mean, median, stdev])

columns = ['journal', 'mean', 'median', 'stdev']
j_cost_stats = pd.DataFrame(data, columns=columns)
j_cost_stats
# Out:
#                                                journal           mean  \
# 0                               psychological medicine    1617.000000
# 1                                    biomacromolecules    2381.040000
# 2                       journal of medicinal chemistry    1052.490769
# 3                            journal organic chemistry     685.880000
# 4                         journal of proteome research    1844.915000
# 5                               molecular pharmacology     649.330000
# 6                                 acs chemical biology    1418.186000
# 7         journal of chemical information and modeling    1329.690000
# 8                                         biochemistry     665.640000
# 9                                     gastroenterology    1233.040000
# 10                 the journal of biological chemistry   29515.744085
# 11                                  journal immunology    1954.870000
# 12                           acs chemical neuroscience    1186.800000
# 13                                            acs nano     668.140000
# 14                           american chemical society    1533.290000
# 15                                analytical chemistry    1718.836667
# 16                              bioconjugate chemistry    1565.260000
# 17            journal of the american chemical society    1626.140000
# 18                                               chest    2383.940000
# 19                      the journal of neurophysiology    1399.127143
# 20                               journal of physiology  126783.231250
# 21                      american journal of psychiatry    2350.875000
# 22                             behavioral neuroscience    3147.706667
# 23                                             emotion    2534.530000
# 24                                   health psychology    3188.300000
# 25                      journal of abnormal psychology    2534.530000
# 26       journal of consulting and clinical psychology    3037.860000
# 27   journal of experimental psychology   animal be...    3144.240000
# 28   journal of experimental psychology  human perc...    2610.360000
# 29                        journal of family psychology    3092.180000
# ..                                                 ...            ...
# 747                                acta opthalmologica    2270.160000
# 748                american journal of transplantation    2052.946667
# 749            angewandte chemie international edition    2437.190000
# 750                                          centaurus    2292.030000
# 751                criminal behavior and mental health    2377.650000
# 752                             depression and anxiety    2368.420000
# 753                               dermatologic surgery    2257.560000
# 754                            economic history review    1901.020000
# 755                                                hpb    2311.560000
# 756    international journal of experimental pathology    2320.030000
# 757                   journal of comparative neurology    1909.730000
# 758         journal of evaluation in clinical practice    2301.530000
# 759                              journal of microscopy    2400.000000
# 760                     journal of orthopedic research    2374.520000
# 761                         journal of viral hepatitis    2350.490000
# 762                                    obesity reviews    2324.295000
# 763                             statistics in medicine     791.190000
# 764                                            synapse    1961.680000
# 765                         zoonoses and public health    2272.150000
# 766                                 angew chems int ed    3026.170000
# 767                                        chemmedchem    1932.546667
# 768                                          protemics    1409.960000
# 769                   journal of small animal practice    2400.000000
# 770                                               aids    2059.306667
# 771                                       aids journal    2015.720000
# 772                                            aids uk    1836.920000
# 773                                              jaids    1749.156667
# 774                                    journal of aids    2009.650000
# 775                               circulation research    1334.150000
# 776                       pediatr infectious disease j    1834.770000
#
#        median          stdev
# 0    1917.000     800.416642
# 1    2381.040            NaN
# 2    1006.720     548.723422
# 3     685.880            NaN
# 4    1844.915     739.683191
# 5     649.330            NaN
# 6    1294.590     507.309560
# 7    1329.690            NaN
# 8     665.640            NaN
# 9    1233.040    1407.085926
# 10   1324.570  166402.487895
# 11   1932.690     827.116630
# 12   1186.800            NaN
# 13    668.140      35.708892
# 14   1533.290            NaN
# 15   2082.740     838.678951
# 16   1565.260            NaN
# 17   1626.140            NaN
# 18   2383.940            NaN
# 19   1319.170     136.805726
# 20   2157.940  352832.623849
# 21   2350.875       1.209153
# 22   3209.630     109.112900
# 23   2534.530            NaN
# 24   3188.300            NaN
# 25   2534.530            NaN
# 26   3037.860            NaN
# 27   3144.240            NaN
# 28   2610.360      69.239896
# 29   3092.180            NaN
# ..        ...            ...
# 747  2270.160            NaN
# 748  1900.700     278.022730
# 749  2437.190       0.000000
# 750  2292.030            NaN
# 751  2377.650            NaN
# 752  2368.420            NaN
# 753  2257.560            NaN
# 754  1901.020            NaN
# 755  2311.560            NaN
# 756  2320.030            NaN
# 757  1909.730            NaN
# 758  2301.530      37.490802
# 759  2400.000            NaN
# 760  2374.520            NaN
# 761  2350.490            NaN
# 762  2324.295      69.685373
# 763   791.190            NaN
# 764  1961.680            NaN
# 765  2272.150            NaN
# 766  3026.170            NaN
# 767  1816.700     203.960766
# 768  1409.960            NaN
# 769  2400.000            NaN
# 770  1968.630     281.067979
# 771  2015.720            NaN
# 772  1836.920       0.000000
# 773  1836.920     338.128049
# 774  2009.650            NaN
# 775  1334.150            NaN
# 776  1834.770            NaN
#
# [777 rows x 4 columns]
